# %%
from matplotlib import pyplot as plt
from pylab import legend
ratio_of_FreiHAND = [100, 95, 90, 85,80,75,70,65,60,55,50,45,40]
MPJPE = [8.38, 6.73, 2.95, 3.11,3.11,3.42,3.92,3.69,2.97,3.87,3.49,3.28,3.39]
plt.plot(ratio_of_FreiHAND, MPJPE, marker = 'o')
plt.xlabel('ratio of FreiHAND')
plt.ylabel('MPJPE(mm)')
plt.title('MPJPE according to ratio of FreiHAND')
legend(['MPJPE'], loc='best')
plt.show()
